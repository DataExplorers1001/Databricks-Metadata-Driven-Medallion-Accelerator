# %%
dbutils.notebook.run("./generate_bronze", 0)
dbutils.notebook.run("./generate_silver", 0)
dbutils.notebook.run("./generate_gold", 0)
dbutils.notebook.run("./generate_lineage", 0)
dbutils.notebook.run("./generate_pipeline_config", 0)
dbutils.notebook.run("./generate_workflow", 0)
