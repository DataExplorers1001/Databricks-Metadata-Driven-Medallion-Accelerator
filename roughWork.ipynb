# %%
spark.table('accelerator.metadata.schema_drift_audit').display()

# %%
# %sql
truncate table accelerator.metadata.schema_drift_audit

# %%
spark.table('accelerator.metadata.schema_history').display()

# %%
spark.table('accelerator.metadata.schema_history').display()

# %%
# %sql
describe table accelerator.metadata.schema_drift_audit

# %%
# %sql
create table accelerator.metadata.schema_drift_audit
(
    table_name	string,
    drift_type	string,
    column_name	string,
    old_data_type	string,
    new_data_type	string,
    detected_on	timestamp

)

# %%
# %sql
ALTER TABLE accelerator.gold.bronze_customer
REPLACE COLUMNS (
    Id STRING,
    Name	string,
Location	string,
mobileNumber	BIGINT,
_rescued_data	string
    
);

# %%
# %sql
ALTER TABLE accelerator.gold.bronze_customer
ALTER COLUMN mobileNumber TYPE BIGINT;

# %%
# %sql
CREATE OR REPLACE TABLE accelerator.gold.bronze_customer
(Id	string,
Name	string,
Location	string,
mobileNumber	bigint,
_rescued_data	string)

# %%
# %sql
DROP TABLE accelerator.gold.bronze_customer_new;

-- ALTER TABLE accelerator.gold.bronze_customer_new
-- RENAME TO bronze_customer;

# %%
accelerator.metadata.schema_drift_audit

# %%
 # %sql
SHOW TABLES IN system.lakeflow;

# %%
# %sql
SHOW SCHEMAS IN system;

# %%
# %sql
SHOW TABLES IN system.lakeflow;

# %%
# %sql
select * from system.lakeflow.job_run_timeline
 --order by create_time

# %%
# %sql
DESCRIBE system.lakeflow.pipelines;

# %%
# %sql
DESCRIBE system.lakeflow.job_run_timeline;

# %%
# %sql
DESCRIBE system.lakeflow.job_task_run_timeline;

# %%
# %sql
drop table  accelerator.gold.bronze_customer;
drop table  accelerator.gold.bronze_product;
drop table accelerator.gold.gold_customer;
drop table accelerator.gold.gold_product;
drop table accelerator.gold.silver_customer;
drop table accelerator.gold.silver_product;

# %%
# %sql
truncate table accelerator.metadata.schema_drift_audit;
truncate table accelerator.metadata.schema_history
